# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
import math

# %%
def central_tendencies(data):
    mean = np.mean(data)
    median = np.median(data)
    values, counts = np.unique(data, return_counts=True)
    mode_index = np.argmax(counts)
    mode = values[mode_index]
    return round(mean,2), round(median,2), round(mode,2)

def dispersion(data):
    variance = np.var(data)
    std_dev = np.std(data)
    minimum = np.min(data)
    maximum = np.max(data)
    range = np.max(data) - np.min(data)
    quartile1 = np.percentile(data, 25)
    quartile3 = np.percentile(data, 75)
    interquartile_range = quartile3 - quartile1
    return round(variance,2), round(std_dev,2), round(minimum,2), round(maximum,2), round(range,2), round(quartile1,2), round(quartile3,2), round(interquartile_range,2)

# %%
h_data = pd.read_csv('Cumulative_WHO_data.csv')
h_data
# Out:
#                                       Name       WHO Region  \
# 0                                  Belarus           Europe
# 1                                    China  Western Pacific
# 2                            French Guiana         Americas
# 3                                   Latvia           Europe
# 4         Saint Vincent and the Grenadines         Americas
# ..                                     ...              ...
# 229                              Argentina         Americas
# 230       Democratic Republic of the Congo           Africa
# 231                                  Nepal  South-East Asia
# 232  Democratic People's Republic of Korea  South-East Asia
# 233                           Turkmenistan           Europe
#
#      Cases - cumulative total  Cases - cumulative total per 100000 population  \
# 0                      994048                                         10520.0
# 1                    99381761                                          6755.0
# ...

# %%
h_total_cases=h_data["Cases - cumulative total"]
h_total_deaths=h_data["Deaths - cumulative total"]
h_per100_cases=h_data["Cases - cumulative total per 100000 population"]
h_per100_deaths=h_data["Deaths - cumulative total per 100000 population"]
h_total_cases=np.array(h_total_cases)
h_total_deaths=np.array(h_total_deaths)
h_per100_cases=np.array(h_per100_cases)
h_per100_deaths=np.array(h_per100_deaths)
# h_total_deaths

# %%
plt.boxplot(h_per100_cases,showfliers=False,vert=False)
plt.title("Total cases per 100000 population")
plt.xlabel("Total cases")
plt.show()

# %%
plt.boxplot(h_per100_deaths,showfliers=False,vert=False)
plt.title("Total deaths per 100000 population")
plt.ylabel("Total deaths")
plt.show()

# %%
plt.boxplot(h_total_cases,showfliers=False,vert=False)
plt.title("Total cases")
plt.ylabel("Total cases")
plt.show()

# %%
plt.boxplot(h_total_deaths,showfliers=False,vert=False)
plt.title("Total deaths")
plt.ylabel("Total deaths")
plt.show()

# %%
h_total_cases_mean, h_total_cases_median, h_total_cases_mode = central_tendencies(h_total_cases)
h_total_cases_variance, h_total_cases_std_dev, h_total_cases_min,h_total_cases_max, h_total_cases_range, h_total_cases_quartile1, h_total_cases_quartile3, h_total_cases_interquartile_range = dispersion(h_total_cases)    
h_total_deaths_mean, h_total_deaths_median, h_total_deaths_mode = central_tendencies(h_total_deaths)    
h_total_deaths_variance, h_total_deaths_std_dev, h_total_deaths_min,h_total_deaths_max, h_total_deaths_range, h_total_deaths_quartile1, h_total_deaths_quartile3, h_total_deaths_interquartile_range = dispersion(h_total_deaths)
h_per100_cases_mean, h_per100_cases_median, h_per100_cases_mode = central_tendencies(h_per100_cases)
h_per100_cases_variance, h_per100_cases_std_dev, h_per100_cases_min,h_per100_cases_max, h_per100_cases_range, h_per100_cases_quartile1, h_per100_cases_quartile3, h_per100_cases_interquartile_range = dispersion(h_per100_cases)
h_per100_deaths_mean, h_per100_deaths_median, h_per100_deaths_mode = central_tendencies(h_per100_deaths)
h_per100_deaths_variance, h_per100_deaths_std_dev, h_per100_deaths_min,h_per100_deaths_max, h_per100_deaths_range, h_per100_deaths_quartile1, h_per100_deaths_quartile3, h_per100_deaths_interquartile_range = dispersion(h_per100_deaths)
print("Total Cases:")
print("Mean:", h_total_cases_mean)
print("Median:", h_total_cases_median)
# print("Mode:", h_total_cases_mode)
print("Variance:", h_total_cases_variance)
print("Standard Deviation:", h_total_cases_std_dev)
print("Minimum:", h_total_cases_min)
print("Maximum:", h_total_cases_max)
print("Range:", h_total_cases_range)
print("Quartile 1:", h_total_cases_quartile1)
print("Quartile 3:", h_total_cases_quartile3)
print("Interquartile Range:", h_total_cases_interquartile_range)
# Out:
# Total Cases:
# Mean: 3322728.15
# Median: 189095.0
# Variance: 130117038980604.92
# Standard Deviation: 11406885.6
# Minimum: 0
# Maximum: 103436829
# Range: 103436829
# Quartile 1: 25316.25
# Quartile 3: 1272514.5
# Interquartile Range: 1247198.25

# %%
print("Total Deaths:")
print("Mean:", h_total_deaths_mean)
print("Median:", h_total_deaths_median)
# print("Mode:", h_total_deaths_mode)
print("Variance:", h_total_deaths_variance)
print("Standard Deviation:", h_total_deaths_std_dev)
print("Minimum:", h_total_deaths_min)
print("Maximum:", h_total_deaths_max)
print("Range:", h_total_deaths_range)
print("Quartile 1:", h_total_deaths_quartile1)
print("Quartile 3:", h_total_deaths_quartile3)
print("Interquartile Range:", h_total_deaths_interquartile_range)
# Out:
# Total Deaths:
# Mean: 30302.41
# Median: 1736.5
# Variance: 11707439381.11
# Standard Deviation: 108200.92
# Minimum: 0
# Maximum: 1218325
# Range: 1218325
# Quartile 1: 173.25
# Quartile 3: 13768.25
# Interquartile Range: 13595.0

# %%
print("Total Cases per 100000 population:")
print("Mean:", h_per100_cases_mean)
print("Median:", h_per100_cases_median)
# print("Mode:", h_per100_cases_mode)
print("Variance:", h_per100_cases_variance)
print("Standard Deviation:", h_per100_cases_std_dev)
print("Minimum:", h_per100_cases_min)
print("Maximum:", h_per100_cases_max)
print("Range:", h_per100_cases_range)
print("Quartile 1:", h_per100_cases_quartile1)
print("Quartile 3:", h_per100_cases_quartile3)
print("Interquartile Range:", h_per100_cases_interquartile_range)
# Out:
# Total Cases per 100000 population:
# Mean: 20571.5
# Median: 13760.0
# Variance: 431931267.54
# Standard Deviation: 20782.96
# Minimum: 0.0
# Maximum: 80260.0
# Range: 80260.0
# Quartile 1: 1913.25
# Quartile 3: 33269.0
# Interquartile Range: 31355.75

# %%
print("Total Deaths per 100000 population:")
print("Mean:", h_per100_deaths_mean)
print("Median:", h_per100_deaths_median)
# print("Mode:", h_per100_deaths_mode)
print("Variance:", h_per100_deaths_variance)
print("Standard Deviation:", h_per100_deaths_std_dev)
print("Minimum:", h_per100_deaths_min)
print("Maximum:", h_per100_deaths_max)
print("Range:", h_per100_deaths_range)
print("Quartile 1:", h_per100_deaths_quartile1)
print("Quartile 3:", h_per100_deaths_quartile3)
print("Interquartile Range:", h_per100_deaths_interquartile_range)
# Out:
# Total Deaths per 100000 population:
# Mean: 125.9
# Median: 82.0
# Variance: 17242.9
# Standard Deviation: 131.31
# Minimum: 0.0
# Maximum: 670.0
# Range: 670.0
# Quartile 1: 14.25
# Quartile 3: 206.0
# Interquartile Range: 191.75

# %%
h_who_region = h_data["WHO Region"]
h_countries,counts=np.unique(h_who_region,return_counts=True)


africa = h_data[h_data["WHO Region"]=="Africa"]
americas = h_data[h_data["WHO Region"]=="Americas"]
eastern_mediterranean = h_data[h_data["WHO Region"]=="Eastern Mediterranean"]
europe = h_data[h_data["WHO Region"]=="Europe"]
south_east_asia = h_data[h_data["WHO Region"]=="South-East Asia"]
western_pacific = h_data[h_data["WHO Region"]=="Western Pacific"]

# %%
for country in h_countries:
    print(country,":")
    country_data = h_data[h_data["WHO Region"]==country]
    country_total_cases = country_data["Cases - cumulative total"]
    country_total_deaths = country_data["Deaths - cumulative total"]
    country_per100_cases = country_data["Cases - cumulative total per 100000 population"]
    country_per100_deaths = country_data["Deaths - cumulative total per 100000 population"]
    mean, median, mode = central_tendencies(country_total_cases)
    variance, std_dev,minimum,maximum ,range, quartile1, quartile3, interquartile_range = dispersion(country_total_cases)
    # print("\n")
    print("Total Cases:")
    print("Mean:", mean)
    print("Median:", median)
    # print("Mode:", mode)
    print("Variance:", variance)
    print("Standard Deviation:", std_dev)
    print("Minimum:", minimum)
    print("Maximum:", maximum)
    print("Range:", range)
    print("Quartile 1:", quartile1)
    print("Quartile 3:", quartile3)
    print("Interquartile Range:", interquartile_range)
    print("\n")
    mean, median, mode = central_tendencies(country_total_deaths)
    variance, std_dev,minimum,maximum ,range, quartile1, quartile3, interquartile_range = dispersion(country_total_deaths)
    print("Total Deaths:")
    print("Mean:", mean)
    print("Median:", median)
    # print("Mode:", mode)
    print("Variance:", variance)
    print("Standard Deviation:", std_dev)
    print("Minimum:", minimum)
    print("Maximum:", maximum)
    print("Range:", range)
    print("Quartile 1:", quartile1)
    print("Quartile 3:", quartile3)
    print("Interquartile Range:", interquartile_range)
    print("\n")
    mean, median, mode = central_tendencies(country_per100_cases)
    variance, std_dev,minimum,maximum ,range, quartile1, quartile3, interquartile_range = dispersion(country_per100_cases)
    print("Total Cases per 100000 population:")
    print("Mean:", mean)
    print("Median:", median)
    # print("Mode:", mode)
    print("Variance:", variance)
    print("Standard Deviation:", std_dev)
    print("Minimum:", minimum)
    print("Maximum:", maximum)
    print("Range:", range)
    print("Quartile 1:", quartile1)
    print("Quartile 3:", quartile3)
    print("Interquartile Range:", interquartile_range)
    print("\n")
    mean, median, mode = central_tendencies(country_per100_deaths)
    variance, std_dev,minimum,maximum ,range, quartile1, quartile3, interquartile_range = dispersion(country_per100_deaths)
    print("Total Deaths per 100000 population:")
    print("Mean:", mean)    
    print("Median:", median)
    # print("Mode:", mode)
    print("Variance:", variance)
    print("Standard Deviation:", std_dev)
    print("Minimum:", minimum)
    print("Maximum:", maximum)
    print("Range:", range)
    print("Quartile 1:", quartile1)
    print("Quartile 3:", quartile3)
    print("Interquartile Range:", interquartile_range)
    print("\n")
    print("\n")
# Out:
# Africa :
# Total Cases:
# Mean: 191752.44
# Median: 59227.5
# Variance: 323705847591.29
# Standard Deviation: 568951.53
# Minimum: 2166
# Maximum: 4072925
# Range: 4070759
# Quartile 1: 19693.75
# Quartile 3: 172291.25
# Interquartile Range: 152597.5
#
#
# Total Deaths:
# Mean: 3510.64
# Median: 789.0
# Variance: 203707342.11
# Standard Deviation: 14272.61
# Minimum: 0
# Maximum: 102595
# Range: 102595
# Quartile 1: 188.75
# Quartile 3: 1973.5
# Interquartile Range: 1784.75
#
#
# Total Cases per 100000 population:
# Mean: 5135.12
# Median: 505.5
# Variance: 144235838.59
# Standard Deviation: 12009.82
# Minimum: 39.0
# Maximum: 55243.0
# Range: 55204.0
# Quartile 1: 288.75
# Quartile 3: 1875.25
# Interquartile Range: 1586.5
#
#
# Total Deaths per 100000 population:
# Mean: 29.18
# Median: 7.5
# Variance: 2175.51
# Standard Deviation: 46.64
# Minimum: 0.0
# Maximum: 175.0
# Range: 175.0
# Quartile 1: 3.0
# Quartile 3: 21.75
# Interquartile Range: 18.75
#
#
#
#
# Americas :
# ...

# %%
import pandas as pd

# Create an empty list to store the results
results = []

for country in h_countries:
    country_data = h_data[h_data["WHO Region"] == country]
    
    stats = {
        "Metric": [],
        "Mean": [],
        "Median": [],
        "Variance": [],
        "Standard Deviation": [],
        "Minimum": [],
        "Maximum": [],
        "Range": [],
        "Quartile 1": [],
        "Quartile 3": [],
        "Interquartile Range": []
    }
    
    metrics = {
        "Total Cases": country_data["Cases - cumulative total"],
        "Total Deaths": country_data["Deaths - cumulative total"],
        "Cases per 100K": country_data["Cases - cumulative total per 100000 population"],
        "Deaths per 100K": country_data["Deaths - cumulative total per 100000 population"],
    }
    
    for metric_name, metric_data in metrics.items():
        mean, median, mode = central_tendencies(metric_data)
        variance, std_dev, minimum, maximum, rnge, quartile1, quartile3, interquartile_range = dispersion(metric_data)
        
        stats["Metric"].append(metric_name)
        stats["Mean"].append(mean)
        stats["Median"].append(median)
        stats["Variance"].append(variance)
        stats["Standard Deviation"].append(std_dev)
        stats["Minimum"].append(minimum)
        stats["Maximum"].append(maximum)
        stats["Range"].append(rnge)
        stats["Quartile 1"].append(quartile1)
        stats["Quartile 3"].append(quartile3)
        stats["Interquartile Range"].append(interquartile_range)

    # Convert dictionary to DataFrame
    df = pd.DataFrame(stats)
    
    # Print country name and table
    print(f"\nStatistics for {country}:")
    print(df.to_string(index=False))
    print("\n" + "-"*80 + "\n")
# Out:
# Statistics for Africa:
#          Metric      Mean  Median     Variance  Standard Deviation  Minimum   Maximum     Range  Quartile 1  Quartile 3  Interquartile Range
#     Total Cases 191752.44 59227.5 3.237058e+11           568951.53   2166.0 4072925.0 4070759.0    19693.75   172291.25            152597.50
#    Total Deaths   3510.64   789.0 2.037073e+08            14272.61      0.0  102595.0  102595.0      188.75     1973.50              1784.75
#  Cases per 100K   5135.12   505.5 1.442358e+08            12009.82     39.0   55243.0   55204.0      288.75     1875.25              1586.50
# Deaths per 100K     29.18     7.5 2.175510e+03               46.64      0.0     175.0     175.0        3.00       21.75                18.75
#
# --------------------------------------------------------------------------------
#
#
# Statistics for Americas:
# ...
